# %%
from ultralytics import YOLO

model = YOLO(
    "runs/classify/hasil_training/beras_cls/weights/best.pt"
)

metrics = model.val()

print(metrics)
# Out:
# Ultralytics 8.4.47  Python-3.10.9 torch-2.11.0+cpu CPU (AMD Ryzen 5 7535HS with Radeon Graphics)
# YOLO11n-cls summary (fused): 47 layers, 1,531,148 parameters, 0 gradients, 3.2 GFLOPs
# train: D:\kuliah\Semester 6\Pembelajaran Mesin\AAAAAAAAAA\dataset\train... found 1207 images in 4 classes
# val: D:\kuliah\Semester 6\Pembelajaran Mesin\AAAAAAAAAA\dataset\valid... found 115 images in 4 classes
# test: D:\kuliah\Semester 6\Pembelajaran Mesin\AAAAAAAAAA\dataset\test... found 57 images in 4 classes
# val: Fast image access  (ping: 0.10.0 ms, read: 45.65.0 MB/s, size: 8.3 KB)
# val: Scanning D:\kuliah\Semester 6\Pembelajaran Mesin\AAAAAAAAAA\dataset\valid... 115 images, 0 corrupt: 100% ━━━━━━━━━━━━ 115/115  0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 8.8it/s 0.9s0.3s
#                    all          1          1
# Speed: 0.0ms preprocess, 5.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# ...
