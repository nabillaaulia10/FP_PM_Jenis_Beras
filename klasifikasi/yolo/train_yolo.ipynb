# %%
from ultralytics import YOLO

model = YOLO("yolo11n-cls.pt")

# %%
# !pip install ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO

model = YOLO("yolo11n-cls.pt")

model.train(
    data="../dataset",
    epochs=50,
    imgsz=224,
    batch=16,
    project="hasil_training",
    name="beras_cls"
)
# Out:
# c:\Users\Nabila\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.5.0) or chardet (7.4.0.post2)/charset_normalizer (3.4.2) doesn't match a supported version!
#   warnings.warn(
# New https://pypi.org/project/ultralytics/8.4.71 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.47  Python-3.10.9 torch-2.11.0+cpu CPU (AMD Ryzen 5 7535HS with Radeon Graphics)
# ...
